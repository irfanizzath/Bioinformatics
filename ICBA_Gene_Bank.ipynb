# %% [markdown]
# <a href="https://colab.research.google.com/github/irfanizzath/Bioinformatics/blob/main/ICBA_Gene_Bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **ICBA Gene Bank**

# %% [markdown]
# **Errors to be Noted (Missing errors in the Error Sheet)**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Book2.csv')
df.head()
# Out:
#     GB   ES
# 0  1/1  1/1
# 1  1/2  1/1
# 2  1/3  1/1
# 3  1/4  1/1
# 4  1/5  1/1

# %%
print('GB:')
GB = set(df['GB'])
print(GB)
print()
print('ES:')
ES = set(df['ES'])
print(ES)
print()
print(GB-ES)
# Out:
# GB:
# ...

# %%
n_df = pd.DataFrame(list(GB-ES))
n_df.to_csv('missing.csv', index=False)
